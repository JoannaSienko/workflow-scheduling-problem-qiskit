# %%
from plot_utils import plot_histogram_with_different_res, plot_histogram, draw_probability_diagram,draw_energy_diagram

# %%
folder = 'results/docplex-without-modifications/'
filenameEnergy = folder + 'energies.txt'

def summary(filename, title):
    plot_histogram(filename)
    draw_probability_diagram(filename, filenameEnergy, title)

# %%
# energy for all configurations
draw_energy_diagram(filenameEnergy)
# Out:
# correct: 7
# incorrect: 1017

# %%
# Simulator 
filename = folder + 'aer-1000-1000.csv'
summary(filename, 'Experiment 1.1')
# Out:
# all results:  1000
# optimal:  0
# correct res: 277
# incorrect res: 723
# correct configurations: 1
# incorrect configurations: 41

# %%
# simulator, max_iter = 2000, shots = 1000
filename = folder + 'aer-2000-1000.csv'
summary(filename, 'Experiment 1.2')
# Out:
# all results:  1000
# optimal:  0
# correct res: 373
# incorrect res: 627
# correct configurations: 1
# incorrect configurations: 27

# %%
# melbourne max_iter = 1000, shots = 1000
filename = folder + 'melbourne-1000-1000.csv'
draw_probability_diagram(filename, filenameEnergy, 'Experiment 1.3')
plot_histogram_with_different_res(filename, 3)
# Out:
# all results:  1000
# optimal:  0
# correct res: 11
# incorrect res: 989
# correct configurations: 5
# incorrect configurations: 574

# %%
# melbourne max_iter = 2000, shots = 2048
filename = folder + 'melbourne-2000-2048.csv'
draw_probability_diagram(filename, filenameEnergy, 'Experiment 1.4')
plot_histogram_with_different_res(filename, 5)
# Out:
# all results:  2048
# optimal:  3
# correct res: 17
# incorrect res: 2031
# correct configurations: 6
# incorrect configurations: 782
