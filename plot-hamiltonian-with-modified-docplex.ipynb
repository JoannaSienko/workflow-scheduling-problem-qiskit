# %%
from plot_utils import plot_histogram_with_different_res, plot_histogram, draw_probability_diagram,draw_energy_diagram

# %%
folder = 'results/modified-docplex/'
filenameEnergy = folder + 'energies.txt'

def summary(filename, title):
    plot_histogram(filename)
    draw_probability_diagram(filename, filenameEnergy, title)

# %%
# all energies
draw_energy_diagram(filenameEnergy)
# Out:
# correct: 7
# incorrect: 1017

# %%
# simulator, max_iter = 1000, shots = 1000
filename = folder + 'aer-1000-1000.csv'
summary(filename, 'Experiment 2.1')
# Out:
# all results:  1000
# optimal:  799
# correct res: 799
# incorrect res: 201
# correct configurations: 1
# incorrect configurations: 7

# %%
# simulator , max_iter = 2000, shots = 1000
filename = folder + 'aer-2000-1000.csv'
summary(filename, 'Experiment 2.2')
# Out:
# all results:  1000
# optimal:  881
# correct res: 881
# incorrect res: 119
# correct configurations: 1
# incorrect configurations: 5

# %%
# melbourne, max_iter = 1000, shots = 1000
filename = folder + 'melbourne-1000-1000.csv'
plot_histogram_with_different_res(filename, 3)
draw_probability_diagram(filename, filenameEnergy, "Experiment 2.3")
# Out:
# all results:  1000
# optimal:  1
# correct res: 6
# incorrect res: 994
# correct configurations: 4
# incorrect configurations: 579

# %%
# melbourne, max_iter = 2000, shots = 1000
filename = folder + 'melbourne-2000-1000.csv'
plot_histogram_with_different_res(filename, 3)
draw_probability_diagram(filename, filenameEnergy, "Experiment 2.4")
# Out:
# all results:  1000
# optimal:  0
# correct res: 7
# incorrect res: 993
# correct configurations: 4
# incorrect configurations: 538
