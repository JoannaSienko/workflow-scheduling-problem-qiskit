# %%
from plot_utils import plot_histogram_with_different_res, plot_histogram, draw_probability_diagram,draw_energy_diagram

# %%
folder = 'results/created-hamiltonian/'
filenameEnergy = folder + 'energies.txt'

def summary(filename, title):
    plot_histogram(filename)
    draw_probability_diagram(filename, filenameEnergy, title)

# %%
# all energies
draw_energy_diagram(filenameEnergy)
# Out:
# correct: 7
# incorrect: 1017

# %%
# simulator, max_iter = 1000, shots = 1000
filename = folder + 'aer-1000-1000.csv'
summary(filename, 'Experiment 3.1')
# Out:
# all results:  1000
# optimal:  973
# correct res: 973
# incorrect res: 27
# correct configurations: 1
# incorrect configurations: 3

# %%
# simulator, max_iter = 2000, shots = 1024
filename = folder + 'aer-2000-1024.csv'
summary(filename, 'Experiment 3.2')
# Out:
# all results:  1024
# optimal:  1005
# correct res: 1005
# incorrect res: 19
# correct configurations: 1
# incorrect configurations: 2

# %%
# melbourne, max_iter = 1000, shots = 1000
filename = folder + 'melbourne-1000-1000.csv'
plot_histogram_with_different_res(filename, 3)
draw_probability_diagram(filename, filenameEnergy, "Experiment 3.3")
# Out:
# all results:  1000
# optimal:  1
# correct res: 7
# incorrect res: 993
# correct configurations: 4
# incorrect configurations: 570

# %%
# melbourne, max_iter = 2000, shots = 1024
filename = folder + 'melbourne-2000-1024.csv'
plot_histogram_with_different_res(filename, 3)
draw_probability_diagram(filename, filenameEnergy, "Experiment 3.4")
# Out:
# all results:  1024
# optimal:  0
# correct res: 8
# incorrect res: 1016
# correct configurations: 4
# incorrect configurations: 624
